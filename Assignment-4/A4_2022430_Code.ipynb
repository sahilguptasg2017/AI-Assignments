# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import seaborn as sns
from imblearn.over_sampling import SMOTE

# %%
trainDataset = pd.read_csv('train.csv') ; testDataset = pd.read_csv('test.csv')

# %% [markdown]
# Seeing the number of unique values in each column

# %%
for x in trainDataset.columns:
    print(f'For the column {x} there are {trainDataset[x].nunique()} unique values')
# Out:
# For the column index there are 6256 unique values
# For the column Address there are 3223 unique values
# For the column Possesion there are 1 unique values
# For the column Furnishing there are 3 unique values
# For the column Buildup_area there are 944 unique values
# For the column Carpet_area there are 2520 unique values
# For the column Bathrooms there are 85 unique values
# For the column Property_age there are 46 unique values
# For the column Parking there are 10 unique values
# For the column Price there are 755 unique values
# For the column Brokerage there are 1517 unique values
# For the column Floor there are 125 unique values
# For the column Per_sqft_price there are 2501 unique values
# For the column BHK there are 9 unique values
# For the column Total_bedrooms there are 27 unique values

# %% [markdown]
# performing detailed statistical analysis on numerical columns , including calculations for mean , standard deviation , min ,max and percentiles

# %%
trainDataset.describe()
# Out:
#              index  Buildup_area   Carpet_area    Bathrooms  Property_age  \
# count  6256.000000   6256.000000   6256.000000  6256.000000   6256.000000
# mean   4879.818894   1120.690537    864.869801     1.968057      7.519661
# std    2770.439333    735.147038    583.283918     0.911779      7.374092
# min       1.000000    180.000000    150.000000     1.000000      1.000000
# 25%    2494.750000    650.000000    475.000000     1.000000      2.000000
# 50%    4920.500000    950.000000    708.315583     2.000000      5.000000
# 75%    7276.250000   1325.000000   1050.000000     2.000000     10.000000
# max    9546.000000  15000.000000  14000.000000    10.000000     99.000000
#
#            Parking         Price     Brokerage        Floor  Per_sqft_price  \
# count  6256.000000  6.256000e+03  6.256000e+03  6256.000000     6256.000000
# mean      1.298593  3.057852e+07  1.148133e+07    19.885595    23415.351551
# ...
